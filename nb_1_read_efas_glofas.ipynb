# %%
# Script 
import matplotlib.pylab as plt
from cw.io import read_glofas_data, read_efas_data
import numpy as np

# %%
# Example GloFAS plo
day_1_glofas_data = read_glofas_data(2020)
plt.imshow(day_1_glofas_data.values, vmin = 1, vmax = 100, cmap = 'Blues')
plt.show()
# Out:
# Can't create file '/home/esowc31/CW4F_data/glofas/glofas_2020.grib.923a8.idx'
# Traceback (most recent call last):
#   File "/home/esowc31/.conda/envs/CW4F/lib/python3.9/site-packages/cfgrib/messages.py", line 523, in from_indexpath_or_filestream
#     self = cls.from_fieldset(filestream, index_keys, computed_keys)
#   File "/home/esowc31/.conda/envs/CW4F/lib/python3.9/site-packages/cfgrib/messages.py", line 366, in from_fieldset
#     return cls.from_fieldset_and_iteritems(fieldset, iteritems, index_keys, computed_keys)
#   File "/home/esowc31/.conda/envs/CW4F/lib/python3.9/site-packages/cfgrib/messages.py", line 379, in from_fieldset_and_iteritems
#     for field_id, raw_field in iteritems:
#   File "/home/esowc31/.conda/envs/CW4F/lib/python3.9/site-packages/cfgrib/messages.py", line 279, in __iter__
#     for message in self.itervalues():
#   File "/home/esowc31/.conda/envs/CW4F/lib/python3.9/site-packages/cfgrib/messages.py", line 255, in itervalues
# ...

# %%
# Example EFAS plot
day_1_efas_data = read_efas_data(year = 2020)
plt.imshow(day_1_efas_data.values, vmin = 1, vmax = 100, cmap = 'Blues')
plt.show()
# Out:
# /home/esowc31/CW4F_data/efas/efas_2020.grib

# %%
day_1_efas_data.T.plot()
