# %%
# Script 
import matplotlib.pylab as plt
from cw.io import read_efas_data
import numpy as np
import datetime

# %%
efas_data = read_efas_data()
day_data = efas_data.get("dis06").sel(time=datetime.datetime(2019, 10, 24, hour=6))

# %%
plt.imshow(day_data.values, vmin = 1, vmax = 100, cmap = 'Blues')
plt.show()
